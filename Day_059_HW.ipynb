# %% [markdown]
# <a href="https://colab.research.google.com/github/meganhsu/ML100-Days/blob/master/Day_059_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets
from sklearn import decomposition
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %%
print(X.shape)
#print(X[0].reshape(8,8))
# Out:
# (537, 64)

# %%
#print(images_and_labels[:10])

# %%
pca = decomposition.PCA(n_components=64)

# %%
pca.fit(X)
XX = pca.transform(X)
print(XX.shape)
# Out:
# (537, 64)

# %%
images_and_labels = list(zip(X, y))
for index, (image, label) in enumerate(images_and_labels[:10]):
    plt.subplot(2, 5, index + 1)
    plt.axis('off')
    plt.imshow(image.reshape(8,8), cmap=plt.cm.gray_r, interpolation='nearest')
    plt.title('Training: %i' % label)

# %%
len(images_and_labels)
# Out:
# 537

# %%
images_and_labels = list(zip(XX, y))
for index, (image, label) in enumerate(images_and_labels[:10]):
    plt.subplot(2, 5, index + 1)
    plt.axis('off')
    plt.imshow(image.reshape(8,8), cmap=plt.cm.gray_r, interpolation='nearest')
    plt.title('Training: %i' % label)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.gca(projection='3d')
ax.scatter(XX[:, 0], XX[:, 1], XX[:, 2], c=y, cmap=plt.cm.RdYlBu)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
# Out:
# Text(0.5,0,'PC3')
